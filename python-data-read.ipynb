# %%
import pandas as pd

# %%
df = pd.read_csv('data/G-01.txt', delimiter='\t', header=None)

# %% [markdown]
# Pandas uses **DataFrames** to represent data
#
# To see the first $n$ lines of the data use `df.head(n)`
#
# Use `df.tail(n)` to see the last $n$ lines

# %%
df.head(10)
# Out:
#           0        1
# 0  549.6131  92.8586
# 1  550.5773  92.6318
# 2  551.5416  92.4336
# 3  552.5058  92.2695
# 4  553.4700  92.1385
# 5  554.4343  92.0280
# 6  555.3985  91.9119
# 7  556.3627  91.7598
# 8  557.3270  91.5506
# 9  558.2912  91.2848

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3580 entries, 0 to 3579
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3580 non-null   float64
#  1   1       3580 non-null   float64
# dtypes: float64(2)
# memory usage: 56.1 KB

# %%
df.describe()
# Out:
#                  0            1
# count  3580.000000  3580.000000
# mean   2275.108869   108.224470
# std     996.632967     5.567039
# min     549.613100    90.001000
# 25%    1412.361025   105.822750
# 50%    2275.108900   110.885000
# 75%    3137.856725   112.140000
# max    4000.604700   113.770000

# %%
df = df.rename(columns={0: 'Frequency', 1: 'Transmittance'})
df
# Out:
#       Frequency  Transmittance
# 0      549.6131        92.8586
# 1      550.5773        92.6318
# 2      551.5416        92.4336
# 3      552.5058        92.2695
# 4      553.4700        92.1385
# ...         ...            ...
# 3575  3996.7478        97.2012
# 3576  3997.7119        97.1980
# 3577  3998.6763        97.1849
# 3578  3999.6404        97.1638
# 3579  4000.6047        97.1397
#
# [3580 rows x 2 columns]

# %%
# Data Filtering

df[ df['Frequency'] < 600 ]
# Out:
#     Frequency  Transmittance
# 0    549.6131        92.8586
# 1    550.5773        92.6318
# 2    551.5416        92.4336
# 3    552.5058        92.2695
# 4    553.4700        92.1385
# 5    554.4343        92.0280
# 6    555.3985        91.9119
# 7    556.3627        91.7598
# 8    557.3270        91.5506
# 9    558.2912        91.2848
# 10   559.2554        90.9848
# 11   560.2197        90.6846
# 12   561.1839        90.4152
# 13   562.1481        90.1932
# 14   563.1124        90.0602
# 15   564.0766        90.0058
# 16   565.0408        90.0010
# 17   566.0051        90.0157
# 18   566.9693        90.0324
# 19   567.9335        90.0491
# 20   568.8978        90.0749
# 21   569.8620        90.1217
# 22   570.8262        90.1987
# 23   571.7905        90.3091
# 24   572.7547        90.4495
# 25   573.7189        90.6098
# 26   574.6832        90.7724
# 27   575.6474        90.9140
# 28   576.6116        91.0115
# 29   577.5759        91.0512
# 30   578.5401        91.0389
# ...

# %%
import matplotlib.pyplot as plt


plt.plot(df['Frequency'], df['Transmittance'])
plt.xlabel('Frequency (Hz)') 
plt.ylabel('Transmittance (%)')
# Out:
# Text(0, 0.5, 'Transmittance (%)')

# %%
import seaborn as sns

sns.lineplot(data=df, x='Frequency', y='Transmittance')
# Out:
# <Axes: xlabel='Frequency', ylabel='Transmittance'>

# %% [markdown]
# ## Multifile Plotting

# %%
df1 = pd.read_csv('data/G-01.txt', delimiter='\t', header=None)
df2 = pd.read_csv('data/G-02.txt', delimiter='\t', header=None)
df3 = pd.read_csv('data/G-03.txt', delimiter='\t', header=None)

df1 = df1.rename(columns={0: 'Frequency', 1: 'Transmittance'})
df2 = df2.rename(columns={0: 'Frequency', 1: 'Transmittance'})
df3 = df3.rename(columns={0: 'Frequency', 1: 'Transmittance'})

# %%
sns.lineplot(data=df1, x='Frequency', y='Transmittance')
sns.lineplot(data=df2, x='Frequency', y='Transmittance')
sns.lineplot(data=df3, x='Frequency', y='Transmittance')
# Out:
# <Axes: xlabel='Frequency', ylabel='Transmittance'>

# %%
df = pd.DataFrame()

df['Frequency'] = df1['Frequency']
df['Transmittance (Graphine)'] = df1['Transmittance']
df['Transmittance (Triazine)'] = df2['Transmittance']
df['Transmittance (Complex)'] = df3['Transmittance']

# %%
df
# Out:
#       Frequency  Transmittance (Graphine)  Transmittance (Triazine)  \
# 0      549.6131                   92.8586                   96.9577
# 1      550.5773                   92.6318                   96.8367
# 2      551.5416                   92.4336                   96.6893
# 3      552.5058                   92.2695                   96.5203
# 4      553.4700                   92.1385                   96.3387
# ...         ...                       ...                       ...
# 3575  3996.7478                   97.2012                   92.1727
# 3576  3997.7119                   97.1980                   92.1781
# 3577  3998.6763                   97.1849                   92.1792
# 3578  3999.6404                   97.1638                   92.1781
# 3579  4000.6047                   97.1397                   92.1767
#
#       Transmittance (Complex)
# 0                    121.1060
# 1                    120.7480
# 2                    120.2490
# ...

# %%
sns.lineplot(data=df, x='Frequency', y='Transmittance (Graphine)')
sns.lineplot(data=df, x='Frequency', y='Transmittance (Triazine)')
sns.lineplot(data=df, x='Frequency', y='Transmittance (Complex)')
# Out:
# <Axes: xlabel='Frequency', ylabel='Transmittance (Graphine)'>

# %% [markdown]
# ## Saving DataFrames as CSV

# %%
df.to_csv('data/merged.csv', header=False)

# %% [markdown]
# ## Other Types of Plots

# %%
df = pd.read_csv('data/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Dropping a columns

df = df.drop(columns=['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.scatterplot(data=df, x='SepalLengthCm', y='PetalLengthCm', hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>
